# %%
#Importing Libraries for EDA
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **EDA**

# %%
#data input
datan = pd.read_csv("../input/soal-praktek-2022/train.csv")

# %% [markdown]
# # Understanding the Data

# %%
datan
# Out:
#           Id  CurahHujan  Penguapan  SinarMatahari  KecSemburanAngin  \
# 0          0         2.2        4.6            1.1               NaN
# 1          1         0.0        1.4            6.9               NaN
# 2          2         6.0        2.4            3.6              41.0
# 3          3         0.2        1.2            7.0               NaN
# 4          4         0.0        3.6           10.3              35.0
# ...      ...         ...        ...            ...               ...
# 59405  59405         0.0        4.2           10.9               NaN
# 59406  59406         0.0        4.8           11.1               NaN
# 59407  59407         0.0        8.0           11.5               NaN
# 59408  59408         0.0        3.6            7.8               NaN
# 59409  59409         0.0        1.6            0.4               NaN
#
#       ArahAngin  KecAngin  Kelembapan  Tekanan  Awan  Temperatur9Pagi
# ...

# %%
datan.describe()
# Out:
#                  Id    CurahHujan     Penguapan  SinarMatahari  \
# count  59410.000000  54332.000000  52302.000000   49274.000000
# mean   29704.500000      2.145715      5.496239       7.739159
# std    17150.334083      7.026224      3.699727       3.797508
# min        0.000000      0.000000      0.000000       0.000000
# 25%    14852.250000      0.000000      2.800000       5.000000
# 50%    29704.500000      0.000000      5.000000       8.700000
# 75%    44556.750000      0.600000      7.400000      10.700000
# max    59409.000000    206.200000     81.200000      39.000000
#
#        KecSemburanAngin      KecAngin    Kelembapan       Tekanan  \
# count      10156.000000  59410.000000  59410.000000  59410.000000
# mean          41.040075     15.688823     65.939623   1016.951437
# std           13.543644      8.334664     18.627505     15.578354
# min           11.000000      2.000000      0.000000    216.000000
# ...

# %%
datan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59410 entries, 0 to 59409
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                59410 non-null  int64
#  1   CurahHujan        54332 non-null  float64
#  2   Penguapan         52302 non-null  float64
#  3   SinarMatahari     49274 non-null  float64
#  4   KecSemburanAngin  10156 non-null  float64
#  5   ArahAngin         51286 non-null  object
#  6   KecAngin          59410 non-null  float64
#  7   Kelembapan        59410 non-null  float64
#  8   Tekanan           59410 non-null  float64
#  9   Awan              59410 non-null  float64
#  10  Temperatur9Pagi   59410 non-null  float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 5.0+ MB

# %% [markdown]
# * There are 10 data types excluding Id
# * There exist 591410 total data
# * 5410 row and 11 column
# * A few values in **KecSemburanAngin**, **SinarMatahari**, **CerahHujan**, **Penguapan**, **ArahAngin** is Not Available (Not a Number)

# %% [markdown]
# # Checking if the data is normally distributed or skewed

# %%
#Rumus untuk mengetes skewed suatu data
mean = datan.mean()
std = datan.std()
median = datan.median()
print(3*(mean-median)/std)
# Out:
# Id                  0.000000
# CurahHujan          0.916160
# Penguapan           0.402386
# SinarMatahari      -0.759057
# KecSemburanAngin    0.451889
# KecAngin            0.247937
# Kelembapan         -0.170776
# Tekanan            -0.028609
# Awan               -0.806566
# Temperatur9Pagi     0.194015
# dtype: float64
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
#Menghitung skew dari data dan menghilangkan data_data yang tidak ada
datan.skew(axis = 0, skipna = True)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Id                   0.000000
# CurahHujan           7.416800
# Penguapan            2.288488
# SinarMatahari       -0.403417
# KecSemburanAngin     0.959550
# KecAngin             0.938474
# Kelembapan          -0.418932
# Tekanan            -36.420601
# Awan                -0.163318
# Temperatur9Pagi      0.106870
# dtype: float64

# %% [markdown]
# Dapat dilihat bahwa semakin dekat nilai ke 0, maka semakin simetrikal data yang ada. Hal ini berarti:
# * Data **CerahHujan**, **Penguapan**, **KecSemburanAngin**, **KecAngin**, bersifat **Skewed** karena memiliki nilai lebih dari kurang lebih 0.5
# * Data **SinarMatahari**, **Kelembapan**, **Awan**, dan **Temperatur** bersifat **Simetrikal atau Normally distributed**.

# %% [markdown]
# # Data correlation

# %%
sns.pairplot(datan)

# %%
#Menghitung korelasi antar data
datan.corr()
# Out:
#                         Id  CurahHujan  Penguapan  SinarMatahari  \
# Id                1.000000   -0.000194   0.002081      -0.002026
# CurahHujan       -0.000194    1.000000  -0.075904      -0.246352
# Penguapan         0.002081   -0.075904   1.000000       0.366075
# SinarMatahari    -0.002026   -0.246352   0.366075       1.000000
# KecSemburanAngin  0.008694    0.097922   0.205752      -0.056090
# KecAngin         -0.001109    0.053185   0.195273      -0.018141
# Kelembapan        0.000861    0.264978  -0.551087      -0.477633
# Tekanan          -0.010748   -0.181800  -0.297947      -0.106067
# Awan              0.007837    0.218323  -0.199591      -0.671205
# Temperatur9Pagi   0.002928    0.016865   0.592114       0.285613
#
#                   KecSemburanAngin  KecAngin  Kelembapan   Tekanan      Awan  \
# Id                        0.008694 -0.001109    0.000861 -0.010748  0.007837
# CurahHujan                0.097922  0.053185    0.264978 -0.181800  0.218323
# ...

# %% [markdown]
# 3 faktor utama yang mempengaruhi temperature di suatu lingkungan tertentu dapat dilihat adalah:
# * Penguapan
# * Sinar Matahari
# * Kecepatan Semburan Angin

# %% [markdown]
# # Arah Angin dan Temperatur

# %%
#BarPlot untuk arah-arah angin
sns.barplot(x=datan['ArahAngin'], y=datan['Temperatur9Pagi'])
# Out:
# <AxesSubplot:xlabel='ArahAngin', ylabel='Temperatur9Pagi'>

# %% [markdown]
# Tidak terdapat ditemukan banyak perubahan yang disebabkan oleh Arah Angin terhadap temperatur karena ditunjukan di data bahwa temperature tidak berubah banyak, dan bisa jadi ada **faktor lain** yang mengubah temperatur, namun **kebetulan** saja arah angin sedang berhembus ke arah yang didata. Arah angin juga tidak dapat dibilang mempengaruhi temperatur karena tidak terpola dan **tersebar** di semua grafik bar plot
#
# Namun arah angin yang memiliki angka temperatur yang besar adalah arah Selatan Tenggara, Timur Tenggara, Timur, Timur-Timur Laut, dan Tenggara

# %% [markdown]
# # Penguapan dan Temperatur

# %%
#Korelasi Antar Data
datan['Temperatur9Pagi'].corr(datan['Penguapan'])
# Out:
# 0.5921136429795351

# %% [markdown]
# Data korelasi bersifat **plus**, yang berarti data **korelasi secara linear**

# %%
#Bentuk scatter plot dari kedua data
sns.scatterplot(x=datan['Temperatur9Pagi'], y=datan['Penguapan'])
# Out:
# <AxesSubplot:xlabel='Temperatur9Pagi', ylabel='Penguapan'>

# %% [markdown]
# Terlihat dari data di atas bahwa Penguapan dan Temperatur berjalan secara sejajar dan **semakin tinggi temperatur**, maka **tinggi juga penguapan**. Namun kebanyakan data menunjukan bahwa data penguapan hannya dapat meningkat hingga poin tertentu sebelum mendatar.

# %% [markdown]
# # Kelembapan dan Temperatur

# %%
#Korelasi Antar Data
datan['Temperatur9Pagi'].corr(datan['Kelembapan'])
# Out:
# -0.4216468704027488

# %% [markdown]
# Data korelasi bersifat **minus**, yang berarti data bersifat **kebalikan**

# %%
sns.scatterplot(x=datan['Temperatur9Pagi'], y=datan['Kelembapan'])
# Out:
# <AxesSubplot:xlabel='Temperatur9Pagi', ylabel='Kelembapan'>

# %% [markdown]
# **Semakin besar kelembapan**, maka **semakin rendah temperatur** yang ada. Hal ini dapat dilihat dengan kelembapan yang saat temperatur pagi rendah bersifat tinggi, namun saat temperatur sudah mulai meninggi, angka kelembapan mulai menurun

# %% [markdown]
# # **Machine Learning Model**

# %% [markdown]
# # Missing Values

# %%
datan
# Out:
#           Id  CurahHujan  Penguapan  SinarMatahari  KecSemburanAngin  \
# 0          0         2.2        4.6            1.1               NaN
# 1          1         0.0        1.4            6.9               NaN
# 2          2         6.0        2.4            3.6              41.0
# 3          3         0.2        1.2            7.0               NaN
# 4          4         0.0        3.6           10.3              35.0
# ...      ...         ...        ...            ...               ...
# 59405  59405         0.0        4.2           10.9               NaN
# 59406  59406         0.0        4.8           11.1               NaN
# 59407  59407         0.0        8.0           11.5               NaN
# 59408  59408         0.0        3.6            7.8               NaN
# 59409  59409         0.0        1.6            0.4               NaN
#
#       ArahAngin  KecAngin  Kelembapan  Tekanan  Awan  Temperatur9Pagi
# ...

# %%
#Sum of Total Missing Values
datan.isnull().sum().sum()
# Out:
# 79700

# %%
#Erasing the missing values
datan.dropna(inplace=True)
datan.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Outlier

# %%
sns.boxplot(datan['CurahHujan'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='CurahHujan'>

# %%
datan = datan[datan['Penguapan'] < 14]
sns.boxplot(datan['Penguapan'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Penguapan'>

# %%
sns.boxplot(datan['SinarMatahari'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='SinarMatahari'>

# %%
datan = datan[datan['KecSemburanAngin'] < 68]
sns.boxplot(datan['KecSemburanAngin'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='KecSemburanAngin'>

# %%
datan = datan[datan['KecAngin'] < 35]
sns.boxplot(datan['KecAngin'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='KecAngin'>

# %%
datan = datan[datan['Kelembapan'] > 25]
sns.boxplot(datan['Kelembapan'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Kelembapan'>

# %%
datan = datan[datan['Tekanan'] < 1035]
datan = datan[datan['Tekanan'] > 1000]
sns.boxplot(datan['Tekanan'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Tekanan'>

# %%
sns.boxplot(datan['Awan'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Awan'>

# %%
sns.boxplot(datan['Temperatur9Pagi'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Temperatur9Pagi'>

# %% [markdown]
# # Duplicate

# %%
#Duplicated sum
datan.duplicated().sum().sum()
# Out:
# 0

# %%
#Just in case, we drop the duplicates and inplace
datan.drop_duplicates(inplace=True)

# %% [markdown]
# # Non-Numeric and other data types

# %%
datan
# Out:
#           Id  CurahHujan  Penguapan  SinarMatahari  KecSemburanAngin  \
# 2          2         6.0        2.4            3.6              41.0
# 7          7         0.0        2.2            3.3              35.0
# 16        16        23.2        2.4            3.2              59.0
# 19        19         0.0        3.2            1.6              52.0
# 21        21         0.0        1.8           13.6              39.0
# ...      ...         ...        ...            ...               ...
# 50749  50749         0.3        1.3            5.4              41.0
# 50754  50754         9.0        6.2           11.5              48.0
# 50755  50755        42.6        7.0            1.6              37.0
# 50761  50761         0.4        4.2           10.8              54.0
# 50771  50771        35.4       12.2           11.3              37.0
#
#       ArahAngin  KecAngin  Kelembapan  Tekanan  Awan  Temperatur9Pagi
# ...

# %%
#Membuang data yang tidak dibutuhkan dan Non-Numerical Data
datan.drop(['Id', 'ArahAngin'],axis=1, inplace=True)
datan
# Out:
#        CurahHujan  Penguapan  SinarMatahari  KecSemburanAngin  KecAngin  \
# 2             6.0        2.4            3.6              41.0      11.0
# 7             0.0        2.2            3.3              35.0       6.0
# 16           23.2        2.4            3.2              59.0      31.0
# 19            0.0        3.2            1.6              52.0      19.0
# 21            0.0        1.8           13.6              39.0       6.0
# ...           ...        ...            ...               ...       ...
# 50749         0.3        1.3            5.4              41.0      13.0
# 50754         9.0        6.2           11.5              48.0      20.0
# 50755        42.6        7.0            1.6              37.0       9.0
# 50761         0.4        4.2           10.8              54.0      20.0
# 50771        35.4       12.2           11.3              37.0      19.0
#
#        Kelembapan  Tekanan  Awan  Temperatur9Pagi
# 2            95.0   1027.1   7.0              9.7
# ...

# %% [markdown]
# **Seeing target's distribution**

# %%
#Seeing the distribution of target
plt.hist(datan['Temperatur9Pagi'])
plt.xlabel("Temperature")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Random Forest Regression

# %%
#Pandas series to choose target and features
X = datan.iloc[:, :-1]
y = datan.iloc[:, -1] #y here is the data in the last column which is the Temperature
X.shape
# Out:
# (9044, 8)

# %%
y.shape
# Out:
# (9044,)

# %% [markdown]
# **Importing model and Splitting data**

# %%
#Splitting Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33)
#Importing model
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# **The Model**

# %%
#Naming the model and fitting the data
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([18.797, 18.295, 19.576, ..., 22.921, 15.392, 20.054])

# %% [markdown]
# **Accuracy Matrix**

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 15.759458322423702

# %%
#RSME
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 3.9698184243644823

# %% [markdown]
# # **TEST ANSWER**

# %%
test = pd.read_csv("../input/soal-praktek-2022/test.csv")
test
# Out:
#         Id  CurahHujan  Penguapan  SinarMatahari  KecSemburanAngin ArahAngin  \
# 0        0         0.0        8.2           10.4              43.0         U
# 1        1         6.2        2.8           12.2              65.0       SBD
# 2        2         0.0        1.0            0.0              22.0         U
# 3        3         6.1        3.1            2.1              43.0       BBD
# 4        4         0.0        3.0           10.2              30.0       BBL
# ...    ...         ...        ...            ...               ...       ...
# 5637  5637         0.0        4.8           10.0              46.0       UTL
# 5638  5638         0.0        6.6           12.8              35.0       STG
# 5639  5639         0.0        7.4            9.0              35.0        TG
# 5640  5640         0.0        3.8           10.1              41.0         B
# 5641  5641         1.8        0.2            6.3              17.0       UBL
#
#       KecAngin  Kelembapan  Tekanan  Awan
# ...

# %%
test.drop(['ArahAngin'],axis=1, inplace=True)
test.dropna(inplace=True)
test.isnull().sum().sum()
test
# Out:
#         Id  CurahHujan  Penguapan  SinarMatahari  KecSemburanAngin  KecAngin  \
# 0        0         0.0        8.2           10.4              43.0      26.0
# 1        1         6.2        2.8           12.2              65.0      33.0
# 2        2         0.0        1.0            0.0              22.0      11.0
# 3        3         6.1        3.1            2.1              43.0      24.0
# 4        4         0.0        3.0           10.2              30.0       7.0
# ...    ...         ...        ...            ...               ...       ...
# 5637  5637         0.0        4.8           10.0              46.0      24.0
# 5638  5638         0.0        6.6           12.8              35.0      19.0
# 5639  5639         0.0        7.4            9.0              35.0      17.0
# 5640  5640         0.0        3.8           10.1              41.0      17.0
# 5641  5641         1.8        0.2            6.3              17.0       2.0
#
#       Kelembapan  Tekanan  Awan
# ...

# %%
predictor = ['CurahHujan', 'Penguapan', 'SinarMatahari', 'KecSemburanAngin', 'KecAngin', 'Kelembapan', 'Tekanan', 'Awan' ]
test_X = test[predictor]

# %%
predicted_temperature = model.predict(test_X)
print(predicted_temperature)
# Out:
# [24.087 16.988  8.411 ... 23.733 16.075 10.952]

# %%
my_submission = pd.DataFrame({'Id': test.Id, 'Temperatur9Pagi': predicted_temperature})
my_submission.to_csv('submission.csv', index=False)
